# %% [markdown]
# # Generative Chunking for Non-Generative Retrieval
#
# ## Instructions:
# 1. Type in query below.
# 2. In the file menu above select "Run all" under the Runtime menue.
# - Results will print under each of two search-methods below.
#
#
# ## About
# - Search time ~0.1 sec. in colab.
# - Anyone with a google account should be able to use this open-source tool.
# - This will work on a mobile device too (if less easy to use the interface)
# - This code requires python but no downloads or 3rd party instalations.
# - Free and open source.
# - Both TF-IDF and BM-25 are vanilla (standard library) python requiring no other packages.
# - More source-material can be added (process exaplained below).

# %% [markdown]
# A thrifty, slim, portable, scale-able, fast way to search for policy Q&A
# without the expense of foundation-model AI.
#
# Fancier versions can use embedding models/foundation models (see: https://medium.com/@GeoffreyGordonAshbrook/search-with-non-generative-ai-d0a3cc77164b, https://github.com/lineality/arxiv_explorer_tools) but more portable methods have advantages as well.
#
# Another use-case for document processing and document search, is asking questions about institutional policy.
#
# Todo:
# - Add more documents and speeches.
#
# Proof of Concept G.G.Ashbrook 2024.07.13

# %% [markdown]
# # Add your query here:

# %%
# query = "Trade policy"
query = "reproductive rights"

# %% [markdown]
# # Explanation of process

# %% [markdown]
# ### Procedure:
# 1. (as a preliminary shortcut) the following documents were 'chunked' into 1-2 sentence FAQ responses with the format:
# ```
# Question: , Answer: Source:
# ```
# using claud3.5, using this prompt: e.g.
#
# system prompt:
# ```
# document processing, document summarization
# ```
#
# ```
# Using the following text, please produce as strings in a python list of strings, in this format
#
# [
# "Question: {text here}, Answer: {text here}",
# ...
# ]
# individual short Q&A pairs both for each and every piece of information.
# Importantly this list must include, but is not restricted to, summaries of sections of information, especially: What is Biden's policy on X? What is Biden's plan for X?
#
# All information as Q&A AND summaries Q&A.
#
# If the list does not include all questions that can be asked about the document then is not complete.
# Produce a complete list.
#
# Each answer must be short, 1-2 sentences.
# Again the required format is: as strings in a python list of strings:
# [
# "Question: {text here}, Answer: {text here}",
# ...
# ]
#
# ```
#
# A followup check may look like this:
# ```
# Is this complete? Does this list contain every policy question that could be asked of the original material? If no, complete the list.
# ```

# %% [markdown]
# # Sources:
# (exapand to see list)

# %% [markdown]
# - https://joebiden.com/issues/
#
# - https://knowledge.wharton.upenn.edu/article/breakdown-of-the-biden-campaigns-policy-platform/
#
# - https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis
#
# - https://joebiden.com/issues/ (2024.07.13)
#
# - On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view
#
# - 2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf
#
# - May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/"
#
# - July 12, 2024
# Remarks by President Biden at a Campaign Event | Detroit, MI https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/
#
#
# - https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/

# %% [markdown]
# Note: this format of tool can be used for other topics as well, e.g.
#
# https://static.project2025.org/2025_MandateForLeadership_FULL.pdf

# %%
corpus = []

# %% [markdown]
# Source: https://joebiden.com/issues/

# %%
corpus += [
"Question: What is the overall fiscal impact of Biden's platform?, Answer: Over 2021-2030, it would raise $3.375 trillion in new tax revenue while increasing spending by $5.37 trillion, for a net deficit increase of $1.975 trillion.",
"Question: What is Biden's tax policy for households making under $400,000?, Answer: Households with AGI under $400,000 would not see direct tax increases, but may see lower investment returns and wages due to corporate tax changes.",
"Question: What are the largest areas of new spending in Biden's plan?, Answer: The largest new spending areas are education at $1.9 trillion and infrastructure/R&D at $1.6 trillion over ten years.",
"Question: What is the projected long-term impact on federal debt?, Answer: Biden's platform is projected to increase federal debt by 0.1% in 2030, then decrease it by 1.9% in 2040 and 6.1% in 2050.",
"Question: How would Biden's plan affect GDP?, Answer: GDP is projected to decrease by 0.4% in 2030, see no change in 2040, and increase by 0.8% in 2050.",
"Question: What are the main components of Biden's tax plan?, Answer: Key components include raising corporate taxes, implementing a Social Security 'donut hole', repealing TCJA elements for high earners, raising capital gains taxes, and limiting deductions.",
"Question: How would Biden's plan affect the top 1% of earners?, Answer: The top 1% would shoulder about 80% of the tax increases, with those making over $400,000 seeing an average 17.7% decrease in after-tax income.",
"Question: What is Biden's policy on Social Security?, Answer: Biden proposes increasing benefits, especially for low-income retirees, and implementing a new payroll tax 'donut hole' for high earners.",
"Question: What is Biden's healthcare plan?, Answer: Key elements include lowering the Medicare eligibility age to 60, expanding ACA marketplaces, allowing Medicare to negotiate drug prices, and expanding long-term elder care.",
"Question: How would Biden's plan affect prescription drug prices?, Answer: Biden's proposals are estimated to lower average prescription drug prices by roughly 60%.",
"Question: What is Biden's immigration policy?, Answer: Biden proposes a pathway to legal status for undocumented immigrants and aims to restore immigration rates to pre-Trump averages.",
"Question: How would Biden's plan affect housing?, Answer: Biden proposes $650 billion in new housing spending over ten years, including expanding Section 8 housing and creating new affordable housing incentives.",
"Question: What is Biden's education policy?, Answer: Biden proposes universal pre-K, expanded funding for Title I schools, two years of free community college, and free public college for low-income students.",
"Question: How would Biden's plan affect corporate taxes?, Answer: Biden proposes raising the corporate tax rate, imposing a minimum tax on book income, and increasing taxes on foreign profits.",
"Question: What is Biden's infrastructure plan?, Answer: Biden proposes $1.6 trillion in new spending on infrastructure and R&D over ten years, including investments in water infrastructure, high-speed rail, and green technology.",
"Question: How would Biden's plan affect marginal tax rates?, Answer: High-income households would see increased federal effective marginal tax rates, with the largest increase due to the new Social Security 'donut hole' above $400,000.",
"Question: What methodology did PWBM use for economic modeling?, Answer: PWBM used dynamic modeling incorporating effects on labor supply, capital formation, and productivity growth, with separate modules for health, immigration, and public investment.",
"Question: How does Biden's plan compare to pre-TCJA tax rates?, Answer: Under Biden's plan, effective tax rates would still be lower than pre-TCJA rates for all income groups below the top 1%.",
"Question: What is the distributional impact of Biden's tax credits?, Answer: When including major tax credits, all income groups below the 95th percentile would see a net tax decrease on average.",
"Question: How do state income taxes factor into the analysis?, Answer: The analysis includes information on state income tax structures, which vary widely from no income tax to highly progressive systems with top rates over 13%.",
]

# %%
# https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis

corpus += [
"Question: What is Biden's overall tax and spending plan?, Answer: Biden's plan would raise $3.375 trillion in new tax revenue while increasing spending by $5.37 trillion over fiscal years 2021-2030. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's tax plan affect households making under $400,000?, Answer: Households with AGI under $400,000 would not see direct tax increases but may see lower investment returns and wages due to corporate tax increases. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the largest areas of new spending in Biden's plan?, Answer: The largest new spending areas are education at $1.9 trillion and infrastructure/R&D at $1.6 trillion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate taxes?, Answer: Biden plans to raise the corporate tax rate, impose a minimum tax on corporate book income, and raise the tax rate on foreign profits. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for education spending?, Answer: Biden proposes $1.9 trillion in education spending, including universal pre-K, expanded funding for Title I schools, and two years of free community college. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's infrastructure plan?, Answer: Biden proposes $1.6 trillion for infrastructure and R&D, including investments in water infrastructure, high-speed rail, municipal transit, and clean energy R&D. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's housing plan?, Answer: Biden proposes $650 billion in new housing spending, including expanding Section 8 housing vouchers and creating new incentives to build affordable housing. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's Social Security plan?, Answer: Biden proposes increasing Social Security benefits, especially for low-income retirees, at an estimated cost of $290.7 billion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's healthcare plan?, Answer: Biden's plan aims to improve healthcare access and lower costs, including lowering the Medicare eligibility age to 60 and allowing Medicare to negotiate drug prices. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's immigration policy?, Answer: Biden proposes a path to legal status for undocumented immigrants and aims to restore immigration rates to pre-Trump averages. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is the overall budget impact of Biden's platform from 2021-2030?, Answer: Biden's platform would raise $3.375 trillion in new tax revenue while increasing spending by $5.37 trillion, for a net increase in the primary deficit of $1.975 trillion. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the largest areas of new spending in Biden's plan?, Answer: The largest areas of new spending are education at $1.9 trillion over ten years and infrastructure and R&D at $1.6 trillion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's tax plan affect households making under $400,000?, Answer: Households with AGI of $400,000 or less would not see direct tax increases but would see lower investment returns and wages due to corporate tax increases, with an average decrease in after-tax income of 0.9%. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate taxes?, Answer: Biden plans to raise the corporate tax rate, impose a minimum tax on corporate book income, and raise the tax rate on foreign profits. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How much new revenue would Biden's corporate tax changes generate?, Answer: Biden's corporate tax changes are projected to raise $1,438.5 billion in new revenue over the ten-year budget window. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for education spending?, Answer: Biden proposes $1.9 trillion in new education spending over ten years, including universal pre-K, expanded funding for Title I schools, and two years of free public college for low-income students. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the federal debt by 2050?, Answer: Biden's platform is projected to decrease federal debt by 6.1% in 2050 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on Social Security?, Answer: Biden proposes increasing Social Security benefits, especially for low-income retirees, including raising the Special Minimum Benefit and switching to the CPI-E for cost of living adjustments. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How much would Biden's Social Security changes cost?, Answer: Biden's Social Security plan is estimated to increase spending by $290.7 billion over the ten-year budget window. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for healthcare?, Answer: Biden's healthcare plan aims to improve access and decrease costs, including lowering the Medicare eligibility age to 60, expanding ACA marketplaces, and allowing Medicare to negotiate drug prices. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's healthcare plan affect federal spending?, Answer: Biden's healthcare plan, including elder care, is estimated to increase spending by $352 billion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on prescription drug prices?, Answer: Biden proposes allowing Medicare to negotiate drug prices and allowing consumers to import drugs from abroad, potentially lowering average prescription drug prices by 60%. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect GDP in 2050?, Answer: The full Biden platform is projected to increase GDP by 0.8% in 2050 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for housing?, Answer: Biden proposes $650 billion in new housing spending over ten years, including expanding Section 8 housing and creating new incentives to build affordable housing. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's tax plan affect the top 0.1% of earners?, Answer: The top 0.1% would see their effective tax rate increase by 12.4 percentage points when including corporate taxes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on immigration?, Answer: Biden proposes a transition to legal status for undocumented immigrants and aims to restore immigration rates to pre-Trump averages. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's immigration plan affect the U.S. population by 2050?, Answer: Biden's immigration plan is projected to increase the U.S. population by 1.64% by 2050. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for infrastructure and R&D?, Answer: Biden proposes $1.6 trillion in new spending on infrastructure and R&D over ten years, including investments in water infrastructure, high-speed rail, and clean energy R&D. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect average hourly wages in 2050?, Answer: The full Biden platform is projected to increase average hourly wages by 1.5% in 2050 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on capital gains taxes?, Answer: Biden proposes taxing capital gains and dividends at ordinary income rates for high-income earners. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect hours worked in 2030?, Answer: The full Biden platform is projected to decrease hours worked by 2.4% in 2030 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What methodology does PWBM use for economic modeling?, Answer: PWBM uses a dynamic model that accounts for macroeconomic effects, including changes in labor supply, capital formation, and productivity. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does Biden's tax plan compare to pre-TCJA tax rates?, Answer: Biden's plan would result in higher effective tax rates than pre-TCJA for the top 1% of earners, but lower rates for those below the 95th percentile of income. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on capital formation by 2050?, Answer: The full Biden platform is projected to decrease the capital stock by 0.4% in 2050 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does Biden's plan address climate change?, Answer: Biden's plan includes investments in clean energy R&D and infrastructure, as well as eliminating fossil fuel subsidies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on the Child Tax Credit?, Answer: Biden proposes expanding the Child and Dependent Care Tax Credit to cover 50% of child care expenses up to $8,000 per child, limited to two children, and making it fully refundable. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect effective marginal tax rates for high-income earners?, Answer: Biden's plan would significantly increase effective marginal tax rates for those earning over $400,000, primarily due to the 'donut hole' payroll tax policy. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What assumptions does PWBM make about the long-term continuation of Biden's policies?, Answer: PWBM assumes most of Biden's tax and spending policies continue indefinitely, except for some infrastructure and housing provisions that end after 2030. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does Biden's plan address income inequality?, Answer: Biden's plan aims to reduce income inequality through progressive taxation, increased social benefits, and investments in education and affordable housing. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on the Estate Tax?, Answer: Biden proposes eliminating stepped-up basis, which would effectively increase estate taxes for high-value estates. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect state tax policies?, Answer: Biden's plan does not directly change state tax policies, but changes in federal taxes and economic conditions could indirectly impact state tax revenues. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for paid leave?, Answer: Biden proposes implementing the FAMILY Act, which is estimated to cost $547 billion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of public investment?, Answer: PWBM models public investments as contributing to 'public capital' which complements private capital and labor, boosting productivity over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on interest rates?, Answer: The analysis does not provide specific projections for interest rates, but suggests that changes in debt levels and capital formation would likely impact interest rates. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does Biden's plan address the Social Security funding shortfall?, Answer: Biden proposes a new 'Donut Hole' payroll tax on earnings above $400,000 to help fund increased Social Security benefits. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on the Earned Income Tax Credit (EITC)?, Answer: Biden proposes expanding the EITC to childless workers aged 65 and older. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the labor force participation rate?, Answer: While not explicitly stated, the projected changes in hours worked suggest Biden's plan could impact labor force participation, particularly for certain demographic groups. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for student debt?, Answer: The analysis does not provide specific details on Biden's student debt plans, focusing instead on his proposals for future education funding. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for behavioral responses to policy changes?, Answer: PWBM's dynamic model incorporates behavioral responses such as changes in labor supply, saving, and investment decisions in response to policy changes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on economic growth in the short term?, Answer: The analysis projects that Biden's full platform would decrease GDP by 0.4% in 2030 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different industries?, Answer: While not explicitly analyzed, the plan's focus on clean energy, infrastructure, and healthcare suggests these sectors could see significant impacts. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on international trade?, Answer: The analysis does not provide specific details on Biden's trade policies, focusing primarily on domestic economic policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of healthcare policy changes?, Answer: PWBM uses an integrated health model that captures links between changes in health, demographics, and the broader economy, including insurance choices and health outcomes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income mobility?, Answer: While not explicitly analyzed, the plan's investments in education and focus on progressive taxation could impact income mobility over the long term. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different age groups?, Answer: The plan would have varying effects on different age groups, with policies like lowering the Medicare eligibility age particularly impacting those near retirement. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate offshoring?, Answer: Biden proposes raising taxes on foreign profits of U.S. multinationals, which could discourage offshoring. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for uncertainty in long-term projections?, Answer: The analysis does not explicitly discuss methods for handling uncertainty, but presents results for multiple scenarios to show a range of potential outcomes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income volatility?, Answer: While not explicitly analyzed, expanded social benefits and changes to tax credits could potentially reduce income volatility for some households. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the gig economy?, Answer: The analysis does not specifically address the gig economy, but changes in tax policy and labor market conditions could impact this sector. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on wealth taxes?, Answer: While Biden does not propose a direct wealth tax, his plans to tax capital gains at ordinary rates and eliminate stepped-up basis would increase taxes on wealth accumulation. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the interaction between federal and state policies?, Answer: The analysis primarily focuses on federal policies, but acknowledges that state and local governments may adjust their policies in response to federal changes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income inequality by race?, Answer: While the analysis does not provide race-specific projections, policies aimed at low and middle-income households could potentially reduce racial income disparities. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the federal budget deficit over time?, Answer: Biden's plan is projected to increase the deficit in the short term but reduce it in the long term, with debt decreasing by 6.1% by 2050. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on financial regulation?, Answer: The analysis does not provide specific details on Biden's financial regulation policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for demographic changes in its long-term projections?, Answer: PWBM's model incorporates demographic projections, including the effects of immigration policy changes on population growth and age structure. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on entrepreneurship?, Answer: While not explicitly analyzed, changes in tax policy, particularly on business and investment income, could impact entrepreneurship. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different regions of the country?, Answer: The analysis does not provide region-specific projections, but policies focused on particular industries or income groups could have varying regional impacts. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on antitrust enforcement?, Answer: The analysis does not provide specific details on Biden's antitrust policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of education spending on long-term economic outcomes?, Answer: PWBM models education spending as contributing to human capital formation, which increases labor productivity over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on inflation?, Answer: The analysis does not provide specific inflation projections, but changes in government spending, taxes, and economic growth could impact inflation rates. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the U.S. position in the global economy?, Answer: While not explicitly analyzed, changes in tax policy, R&D investment, and economic growth could impact U.S. global competitiveness. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on monetary policy?, Answer: The analysis does not provide details on Biden's views on monetary policy, as this is primarily the domain of the Federal Reserve. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for technological change in its long-term projections?, Answer: While not explicitly discussed, PWBM's projections likely incorporate assumptions about technological progress, particularly in relation to R&D investments. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income mobility across generations?, Answer: While not explicitly analyzed, investments in education and changes to tax policy could potentially impact intergenerational income mobility. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the U.S. energy sector?, Answer: Biden's plan includes significant investments in clean energy R&D and infrastructure, which would likely lead to substantial changes in the energy sector. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on farm subsidies?, Answer: The analysis does not provide specific details on Biden's policies regarding farm subsidies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of housing policy on the broader economy?, Answer: PWBM models housing assistance as transfers to households, which can affect labor supply and consumption decisions. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on economic mobility for immigrants?, Answer: While not explicitly analyzed, Biden's immigration policies and investments in education could potentially improve economic mobility for immigrants. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the federal government's interest payments?, Answer: While not explicitly stated, changes in debt levels would likely impact the government's interest payments over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on tariffs?, Answer: The analysis does not provide specific details on Biden's tariff policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for potential economic shocks in its long-term projections?, Answer: The analysis does not explicitly discuss how potential economic shocks are incorporated into the projections. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the U.S. trade balance?, Answer: While not explicitly analyzed, changes in tax policy and economic growth could potentially impact the U.S. trade balance. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different education levels?, Answer: Biden's education proposals, including free public college for low-income students, could significantly impact educational attainment levels. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on the minimum wage?, Answer: The analysis does not provide specific details on Biden's minimum wage policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of R&D spending on productivity growth?, Answer: PWBM likely models R&D spending as contributing to total factor productivity growth, though specific details are not provided. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the distribution of wealth?, Answer: While not explicitly analyzed, changes in tax policy, particularly on capital gains and estates, could impact wealth distribution over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the healthcare industry?, Answer: Biden's healthcare proposals, including drug price negotiations and expanded coverage, would likely lead to significant changes in the healthcare industry. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate governance?, Answer: The analysis does not provide specific details on Biden's corporate governance policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for changes in life expectancy in its long-term projections?, Answer: While not explicitly discussed, PWBM's demographic projections likely incorporate assumptions about changes in life expectancy. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the federal debt-to-GDP ratio?, Answer: While not explicitly stated, the projections of debt and GDP changes imply that Biden's plan would likely decrease the debt-to-GDP ratio over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different household types (e.g., single parents, retirees)?, Answer: Various policies, such as expanded child care credits and Social Security changes, would have different impacts on different household types. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on occupational licensing?, Answer: The analysis does not provide specific details on Biden's policies regarding occupational licensing. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the interaction between fiscal and monetary policy?, Answer: The analysis does not explicitly discuss how interactions between fiscal and monetary policy are modeled. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income volatility for different income groups?, Answer: While not explicitly analyzed, expanded social benefits and tax credits could potentially reduce income volatility, particularly for lower-income groups. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the U.S. housing market?, Answer: Biden's housing proposals, including expanded housing assistance and first-time homebuyer credits, could significantly impact the housing market. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on worker training programs?, Answer: While not explicitly detailed, Biden's platform likely includes provisions for worker training as part of his education and workforce development plans. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for potential changes in retirement behavior in its projections?, Answer: While not explicitly discussed, PWBM's model likely incorporates assumptions about how policy changes could affect retirement decisions. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the U.S. manufacturing sector?, Answer: Biden's 'Made in America' plan and infrastructure investments could potentially boost the manufacturing sector, though specific projections are not provided. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on green energy incentives?, Answer: While not explicitly detailed, Biden's plan includes significant investments in clean energy R&D and infrastructure, likely involving green energy incentives. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the potential crowding-out effects of government spending?, Answer: PWBM's model likely accounts for crowding-out effects through changes in interest rates and private investment, though specific details are not provided. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income inequality between urban and rural areas?, Answer: While not explicitly analyzed, policies targeting infrastructure, education, and healthcare could potentially impact urban-rural income disparities. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the gig economy and independent contractors?, Answer: The analysis doesn't specifically address this, but changes in tax policy and labor market conditions could impact gig workers and independent contractors. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate tax havens?, Answer: Biden proposes imposing sanctions on tax havens and raising taxes on foreign profits of U.S. multinationals. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for potential changes in birth rates in its long-term projections?, Answer: While not explicitly discussed, PWBM's demographic projections likely incorporate assumptions about birth rates. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on small businesses?, Answer: The analysis doesn't provide specific projections for small businesses, but changes in tax policy and economic conditions would likely impact this sector. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the technology sector?, Answer: While not explicitly analyzed, Biden's R&D investments and potential regulatory changes could significantly impact the tech sector. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on apprenticeship programs?, Answer: The analysis doesn't provide specific details on apprenticeship programs, though these may be part of Biden's broader education and workforce development plans. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the potential effects of climate change on long-term economic projections?, Answer: The analysis doesn't explicitly discuss how climate change effects are incorporated into the economic projections. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the federal government's discretionary spending?, Answer: While not explicitly broken down, Biden's plan includes significant increases in discretionary spending across various areas. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the pharmaceutical industry?, Answer: Biden's proposals to allow Medicare to negotiate drug prices and to allow drug importation would likely significantly impact the pharmaceutical industry. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on consumer protection regulations?, Answer: The analysis doesn't provide specific details on Biden's consumer protection policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for potential changes in migration patterns within the U.S. in its projections?, Answer: While not explicitly discussed, PWBM's model may incorporate assumptions about internal migration patterns. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the U.S. pension system?, Answer: While not explicitly analyzed, changes to Social Security and overall economic conditions could impact the broader pension system. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different sectors of the bond market?, Answer: While not explicitly analyzed, changes in government debt levels and economic conditions could impact various sectors of the bond market. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on data privacy and cybersecurity?, Answer: The analysis doesn't provide specific details on Biden's data privacy and cybersecurity policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the potential effects of automation on the labor market in its long-term projections?, Answer: The analysis doesn't explicitly discuss how potential effects of automation are incorporated into the labor market projections. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income mobility for different racial and ethnic groups?, Answer: While not explicitly analyzed, policies aimed at education, housing, and progressive taxation could potentially impact income mobility for different racial and ethnic groups. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
]

# %% [markdown]
# https://joebiden.com/issues/ (2024.07.13)

# %%
# from https://joebiden.com/issues/ (2024.07.13)

corpus += [
"Question: What is Biden's policy on democracy?, Answer: Biden is committed to strengthening democracy and protecting freedoms, standing up to extremists who undermine the Constitution. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden view the January 6 attack?, Answer: Biden sees it as a dangerous threat to democracy, contrasting with Trump who calls the attackers 'patriots' and 'hostages'. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's plan for the middle class?, Answer: Biden aims to rebuild and grow the middle class by creating jobs, rebuilding infrastructure, and bringing manufacturing back home. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How many jobs have been created under Biden's administration?, Answer: Biden's administration has created more than 15.5 million jobs and a record number of small businesses. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's priority regarding costs for working families?, Answer: Biden's top priority is fighting to lower costs for working families, including prescription drugs, housing, and eliminating junk fees. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to make the tax system fairer?, Answer: Biden plans to reward work over wealth, impose a corporate minimum tax, and ensure those earning under $400,000 won't pay additional federal taxes. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on health care?, Answer: Biden believes health care is a right, not a privilege, and aims to make it more accessible and affordable for all Americans. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How has Biden addressed prescription drug costs?, Answer: Biden has capped insulin costs at $35 a month and yearly out-of-pocket prescription drug costs at $2,000 for Medicare recipients. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's position on reproductive freedom?, Answer: Biden believes reproductive health care decisions should be made by women with their doctors, not politicians, and opposes a national abortion ban. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How has Biden responded to the overturning of Roe v. Wade?, Answer: Biden has taken action to protect and strengthen reproductive health care access, including signing executive orders and fighting for women's rights to emergency medical care. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's plan for job creation?, Answer: Biden plans to continue creating good-paying American jobs, rebuilding infrastructure, and bringing manufacturing back to the US. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden aim to support small businesses?, Answer: Biden has already created a record number of small businesses and plans to continue supporting their growth and development. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on prescription drug prices?, Answer: Biden aims to lower prescription drug prices for all Americans and expand Medicare's ability to negotiate drug prices. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to make housing more affordable?, Answer: Biden plans to make renting and buying homes more affordable, though specific details aren't provided in the text. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on Social Security and Medicare?, Answer: Biden opposes cuts to Social Security and Medicare, contrasting with Trump who is accused of planning to cut these programs. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address inflation?, Answer: Biden plans to fight inflation by cracking down on price gouging and unfair practices by big corporations. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on the Affordable Care Act?, Answer: Biden has strengthened the Affordable Care Act and opposes any attempts to repeal or 'terminate' it. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to support the American Dream?, Answer: Biden aims to ensure every American gets a fair shot at the American Dream by growing the middle class and creating economic opportunities. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on billionaires and taxation?, Answer: Biden believes billionaires should not pay a lower tax rate than working-class Americans and aims to make the ultra-wealthy pay their fair share. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address corporate tax evasion?, Answer: Biden has imposed a 15 percent corporate minimum tax and is cracking down on wealthy tax cheats. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on birth control access?, Answer: Biden supports strengthening access to birth control as part of his reproductive health care policy. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address the national debt?, Answer: The text doesn't provide specific information on Biden's plan to address the national debt. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on the Constitution?, Answer: Biden is committed to protecting and upholding the Constitution, contrasting with Trump who has called for its 'termination'. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to support working families?, Answer: Biden plans to support working families by lowering costs, creating jobs, and providing tax cuts to the middle class. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on manufacturing?, Answer: Biden aims to bring manufacturing back to the US, creating good-paying American jobs and strengthening domestic production. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address unfair junk fees?, Answer: Biden is cracking down on unfair junk fees charged by banks, credit card companies, and airlines to save working families billions. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on the judicial system?, Answer: Biden supports the American judicial system, contrasting with Trump who is attacking it after being criminally convicted. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to protect voting rights?, Answer: While not explicitly stated, Biden's commitment to strengthening democracy implies support for protecting voting rights. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on infrastructure?, Answer: Biden has passed legislation to rebuild America's infrastructure, creating jobs and improving the country's physical foundations. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address income inequality?, Answer: Biden aims to address income inequality by growing the middle class and ensuring the ultra-wealthy pay their fair share in taxes. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on union rights?, Answer: While not explicitly stated, Biden's support for working families and good-paying jobs suggests support for union rights. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address climate change?, Answer: The text doesn't provide specific information on Biden's climate change policy. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on education?, Answer: The text doesn't provide specific information on Biden's education policy. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address gun violence?, Answer: The text doesn't provide specific information on Biden's gun violence policy. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on immigration?, Answer: The text doesn't provide specific information on Biden's immigration policy. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to support veterans?, Answer: The text doesn't provide specific information on Biden's plans for supporting veterans. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on foreign relations?, Answer: The text doesn't provide specific information on Biden's foreign relations policy. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address student loan debt?, Answer: The text doesn't provide specific information on Biden's plans for student loan debt. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on LGBTQ+ rights?, Answer: The text doesn't provide specific information on Biden's stance on LGBTQ+ rights. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address racial equity?, Answer: While not explicitly stated, Biden's policies aim to benefit all Americans, including increased health coverage for Black and Latino Americans. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on clean energy?, Answer: The text doesn't provide specific information on Biden's clean energy policy. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address the opioid crisis?, Answer: The text doesn't provide specific information on Biden's plans for addressing the opioid crisis. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on campaign finance reform?, Answer: The text doesn't provide specific information on Biden's stance on campaign finance reform. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to support rural communities?, Answer: The text doesn't provide specific information on Biden's plans for supporting rural communities. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on cybersecurity?, Answer: The text doesn't provide specific information on Biden's cybersecurity policy. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to address wealth concentration?, Answer: Biden aims to address wealth concentration by making the ultra-wealthy and big corporations pay their fair share in taxes. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's stance on antitrust enforcement?, Answer: While not explicitly stated, Biden's opposition to big corporations taking advantage of working Americans suggests support for antitrust enforcement. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: How does Biden plan to support working parents?, Answer: While not explicitly stated, Biden's policies aim to lower costs and provide tax cuts for middle-class families, which would benefit working parents. Source: https://joebiden.com/issues/ (2024.07.13)",
"Question: What is Biden's policy on public transportation?, Answer: While not explicitly stated, Biden's infrastructure plans likely include improvements to public transportation. Source: https://joebiden.com/issues/ (2024.07.13)",
]

# %%
# from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024
# Blue Bell, Pennsylvania on January 5, 2024
corpus += [
"""Question: What historical event does Biden reference at the beginning of his speech?, Answer: Biden references the Continental Army's winter at Valley Forge in 1777. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say is the most urgent question of our time?, Answer: Biden asks whether democracy is still America's sacred cause. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden characterize Trump's campaign?, Answer: Biden says Trump's campaign is about himself, not America, and is obsessed with the past rather than the future. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What event does Biden focus on from three years ago?, Answer: Biden focuses on the January 6, 2021 insurrection at the U.S. Capitol. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How many police officers were injured on January 6, according to Biden?, Answer: Biden states that over 140 police officers were injured. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden accuse Trump of doing during the Capitol attack?, Answer: Biden accuses Trump of watching the attack on TV and doing nothing to stop it. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How many court cases did Trump lose regarding the 2020 election, according to Biden?, Answer: Biden states that Trump lost 60 court cases. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What is Biden's policy on political violence?, Answer: Biden strongly condemns political violence, stating it has no place in American democracy. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden accuse Trump of promising for the future?, Answer: Biden says Trump is promising a campaign of "revenge and retribution". Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden characterize Trump's language about his opponents?, Answer: Biden says Trump uses language reminiscent of Nazi Germany, calling opponents "vermin" and saying America's blood is being poisoned. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say is on the ballot in the upcoming election?, Answer: Biden says democracy itself is on the ballot, along with various freedoms. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about his commitment as president?, Answer: Biden commits to being a president for all Americans, whether they voted for him or not. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe America's position in the world?, Answer: Biden describes America as still being viewed as a beacon of democracy for the world. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What painting in the Capitol does Biden reference?, Answer: Biden references a painting of George Washington resigning his commission as commander-in-chief. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about America's ability to overcome crises?, Answer: Biden states that America has always come out of every crisis stronger than it went in. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What is Biden's view on the future of America?, Answer: Biden expresses optimism about America's future, believing there's nothing beyond the country's capacity if people act together. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden contrast his vision of America with Trump's?, Answer: Biden presents a vision of America focused on possibilities and unity, contrasting with what he portrays as Trump's focus on carnage and division. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the nature of American patriotism?, Answer: Biden defines American patriotism as believing in America's success and potential, not fostering fear or victimhood. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden characterize the upcoming election?, Answer: Biden describes it as the first national election since the January 6 insurrection "placed a dagger at the throat of American democracy". Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about America's founding principle?, Answer: Biden states that America is the only nation built on an idea - that all men and women are created equal. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What is Biden's plan for preserving democracy?, Answer: Biden pledges to make the defense, protection, and preservation of American democracy the central cause of his presidency. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden view the alternative to democracy?, Answer: Biden states that the alternative to democracy is dictatorship, which he strongly opposes. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about Trump's attitude towards election results?, Answer: Biden claims Trump has said he won't honor the results of the election if he loses. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How many people have been charged in relation to the January 6 attack, according to Biden?, Answer: Biden states that more than 1,200 people have been charged with assault on the Capitol. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about Trump's treatment of January 6 participants?, Answer: Biden claims Trump has called the insurrectionists "patriots" and promised to pardon them if he returns to office. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the 2022 midterm elections?, Answer: Biden states that in the 2022 midterms, election deniers were defeated in state after state. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe Trump's relationship with foreign leaders?, Answer: Biden accuses Trump of admiring authoritarian leaders and dictators. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the role of everyday people in American democracy?, Answer: Biden emphasizes that in America, everyday people govern themselves without a king or dictator. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What is Biden's message about unity in the face of challenges?, Answer: Biden calls for Americans to act together with "one heart" to overcome difficulties, echoing George Washington's words. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe the current state of America?, Answer: Biden insists that America is winning and not failing, despite challenges. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about his commitment to the Constitution?, Answer: Biden implies his strong commitment to the Constitution, contrasting himself with Trump who he accuses of being willing to "terminate" parts of it. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What is Biden's stance on the peaceful transfer of power?, Answer: Biden strongly supports the peaceful transfer of power, criticizing Trump for attempting to overturn the 2020 election results. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden characterize the choice voters face in 2024?, Answer: Biden presents the choice as between preserving democracy and embracing what he describes as Trump's authoritarian tendencies. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the global perception of the U.S. election?, Answer: Biden claims world leaders have expressed concern to him about the possibility of Trump winning, fearing it would put their countries at risk. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe the impact of January 6 on American democracy?, Answer: Biden says January 6 nearly caused America to "lose it all," but that democracy ultimately held together. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the role of ordinary citizens in preserving democracy?, Answer: Biden credits ordinary citizens, state election officials, and the judicial system for putting the Constitution first and ensuring the will of the people prevailed in 2020. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden contrast his campaign with Trump's?, Answer: Biden says his campaign is about America and its future, while Trump's is about Trump himself and the past. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the importance of accepting election results?, Answer: Biden emphasizes that loving one's country means accepting election results even when you lose, criticizing Trump for not doing so. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe the ongoing threat to democracy?, Answer: Biden describes a "determined minority" trying to destroy democracy for their own agenda, but says the American people are standing bravely against this threat. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What is Biden's message about America's resilience?, Answer: Biden expresses confidence in America's ability to overcome challenges, stating that the nation has always emerged stronger from crises. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the legal consequences for January 6 participants?, Answer: Biden states that nearly 900 people have been convicted or pled guilty, with collective sentences totaling over 840 years in prison. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe Trump's attitude towards the Constitution?, Answer: Biden claims Trump said he would 'terminate' parts of the Constitution if it fits his will. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about Trump's plans for using military force domestically?, Answer: Biden alleges Trump plans to invoke the Insurrection Act to deploy U.S. military forces on American streets. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden characterize the difference between his and Trump's approach to power?, Answer: Biden suggests he believes in returning power to the people willingly, while implying Trump seeks to hold onto power relentlessly. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the role of books and education in democracy?, Answer: Biden criticizes those who seek to 'bury history and ban books,' implying support for free access to information. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe the historical pattern of progress in America?, Answer: Biden says every stride forward in America is met with ferocious backlash from those who fear progress. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the composition of the American nation?, Answer: Biden states that America is not built on ethnicity, religion, or geography, but on the idea that all people are created equal. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe the stakes of the 2024 election?, Answer: Biden portrays the election as a choice between preserving democracy and embracing what he sees as Trump's authoritarian tendencies. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about his approach to being president?, Answer: Biden commits to being a president for all Americans, whether they voted for him or not, and says he's done this for the past three years. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe the global reaction to the possibility of Trump winning?, Answer: Biden claims world leaders have privately expressed concern that their countries would be at risk if Trump wins. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the painting of George Washington in the Capitol?, Answer: Biden describes a painting of Washington resigning his commission, presenting it as a symbol of American democracy and peaceful transfer of power. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden contrast American leaders with monarchs or dictators?, Answer: Biden says genuine American leaders return power willingly, unlike monarchs or dictators who hold onto power relentlessly. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the role of grievances in his vision for America?, Answer: Biden states that his vision of America is not weighed down by grievances, contrasting this with Trump's approach. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: How does Biden describe America's position to lead the world?, Answer: Biden states that no country is better positioned to lead the world than America. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
"""Question: What does Biden say about the relationship between progress and democracy?, Answer: Biden argues that without democracy, no progress is possible. Source: Blue Bell, Pennsylvania on January 5, 2024 from https://apnews.com/article/biden-speech-valley-forge-trump-campaign-bda2293cac2b30e49157c2e6fb256d64 Updated 7:30 PM EDT, January 5, 2024""",
]

# %% [markdown]
# On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view

# %%
corpus += [
"""Healthcare, Inflation, cost of living, rising prices: Biden understands that middle-class life is too expensive right now. That is why he has passed laws to lower prescrption drug costs, health care premiums, and energy costs. Source: PA-DEMS On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view""",
"""The Economy, Economics: Biden-Harris have created 15 million jobs, including 800,000 in manufacturing. 16 million small business applications have been filed -- a record high. Unemployment is low at 3.7% in 2024. Source: PA-DEMS On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view""",
"""Healthcare: Biden is focused on capping the cost of insulin at $35/month for everyone (after already capping the cost at $35/month for seniors, and capping out-of-pocket prescription drug costs as $2,000 (for whom?). Source: PA-DEMS On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view""",
"""Joe Biden supports women's rights and is fighting to restore the protections of Roe vs. Wade. He opposes a federal abortion ban. He believes reproductive health care decisions should be made by people and their doctors, not by politicians. Source: PA-DEMS On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view""",
"""Biden has launched an effort to expand access to voter registration and election information. Biden has called on Congress to pass the John Lewis Voting Rights Advancement Act and the Freedom of Vote Act.  Source: PA-DEMS On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view""",
"""Joe Biden grew up in Scranton PA Pennsylvania in a middle-class Irish Catholic family and worked his way up to become a city councilor and a Senator. Source: PA-DEMS On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view""",
""" Source: On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view""",

]

# %% [markdown]
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/
#
#
# " Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/"

# %%
corpus += [
"Question: What organization did Biden first join? Answer: Biden first joined the NAACP when he was 15 years old. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: Why does Biden love Detroit? Answer: Biden loves Detroit because his father was an automobile manager and Detroit put food on their table every night. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What award did Biden receive at this event? Answer: Biden received the James Weldon Johnson Lifetime Achievement Award from the NAACP. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: Who is Biden's campaign co-chair? Answer: Governor Gretchen Whitmer is Biden's campaign co-chair. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's policy on prescription drug costs? Answer: Biden capped insulin costs at $35 a month for seniors and limited total out-of-pocket prescription costs to $2,000 a year for seniors. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for HBCUs? Answer: Biden's administration is investing a record $16 billion in HBCUs. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: How many judges has Biden appointed to the federal bench? Answer: Biden has appointed nearly 200 judges to the federal bench. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's stance on the Affordable Care Act? Answer: Biden protected and expanded the Affordable Care Act, saving millions of families $800 in yearly premiums. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's policy on student debt relief? Answer: Biden's administration has taken significant action on student debt relief, with over 4.5 million Americans having their debts wiped out. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for voting rights? Answer: Biden plans to sign the John Lewis Voting Rights Act and the Freedom to Vote Act if reelected. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: How does Biden view Trump's potential reelection? Answer: Biden believes Trump poses a greater threat in a second term and is running for revenge rather than to lead America. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's vision for America's future? Answer: Biden envisions a future where democracy is defended, freedoms are protected, the middle class has a fair shot, and the full promise of America is available to all Americans. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What does Biden say about diversity in his administration? Answer: Biden claims to have the most diverse administration in history, with more African Americans, women, and minorities than any other administration. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's stance on unions? Answer: Biden describes himself as a 'union guy' and believes that unions built the middle class. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What does Biden say about Trump's tax policies? Answer: Biden claims Trump enacted a $2 trillion tax cut that benefited the wealthy and corporations while exploding the federal deficit. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for Social Security and Medicare? Answer: Biden plans to protect Social Security and Medicare by making the wealthy pay their fair share. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What does Biden say about Trump's response to the COVID-19 pandemic? Answer: Biden criticizes Trump for downplaying the seriousness of the pandemic and suggesting injecting bleach as a treatment. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's stance on gun control? Answer: Biden passed the most significant gun safety law in decades and wants to ban assault weapons again. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What does Biden say about Trump's attitude towards the 2020 election results? Answer: Biden says Trump can't accept that he lost and that 'something snapped' in Trump after the 2020 election. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: How does Biden characterize the January 6th insurrection? Answer: Biden sees the January 6th event as an insurrection unleashed by Trump after failing to legally challenge the election results."
"Question: What is Biden's policy on environmental justice? Answer: Biden's administration is making the most significant investment ever in climate action, including the most substantial action on environmental justice. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for improving internet access? Answer: Biden is delivering affordable high-speed Internet to ensure no child has to do homework in places like McDonald's parking lots. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's policy on Black unemployment? Answer: Biden's policies have resulted in historic lows of Black unemployment. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for Black small businesses? Answer: Biden's policies have led to Black small businesses starting up at the fastest rate in 30 years. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's stance on reproductive rights? Answer: Biden plans to make Roe v. Wade the law of the land again if reelected. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's policy on book banning and Black history education? Answer: Biden opposes book banning and attempts to erase Black history, stating that Black history is American history. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for addressing the racial wealth gap? Answer: Biden's policies have resulted in the racial wealth gap reaching its lowest level in 20 years. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's policy on corporate landlords and rent prices? Answer: Biden is cracking down on corporate landlords to keep rents down. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for reconnecting Black neighborhoods? Answer: Biden is investing in reconnecting Black neighborhoods that were cut off by old highways and decades of disinvestment. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's policy on lead pipes and clean water? Answer: Biden is working to remove every lead pipe to ensure all children can drink clean water without fear of brain damage. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's stance on political violence? Answer: Biden firmly states that political violence has no place in America. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for childcare, eldercare, and paid leave? Answer: Biden envisions a future where the wealthy pay their fair share in taxes to fund childcare, eldercare, paid leave, and other programs. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's policy on Supreme Court appointments? Answer: Biden appointed the first Black woman to the Supreme Court and emphasizes the importance of diverse judicial appointments. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's plan for addressing Black maternal mortality? Answer: While not explicitly stated, Biden acknowledges the higher mortality rate for Black mothers and ties this issue to reproductive rights. Source:  May 19, 2024 Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/05/19/remarks-by-president-biden-at-a-campaign-event-detroit-mi-2/",
"Question: What is Biden's policy on diversity, equity, and inclusion? Answer: Biden views diversity, equity, and inclusion as core strengths of America and has implemented these values in his administration."
]

# %% [markdown]
# Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf

# %%
corpus += [
"Question: What did Biden say about the state of democracy in America? Answer: Biden said freedom and democracy are under assault at home and overseas, comparing it to the time of Lincoln and the Civil War. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: How did Biden characterize the January 6th insurrection? Answer: Biden called it the gravest threat to U.S. democracy since the Civil War and said the insurrectionists were not patriots. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What did Biden say about Ukraine? Answer: Biden said Ukraine can stop Putin if we provide them weapons, and that America will not walk away from supporting Ukraine. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on NATO? Answer: Biden strongly supports NATO, calling it the strongest military alliance in history, and welcomed Finland and Sweden as new members. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What did Biden say about the economy? Answer: Biden said the U.S. economy is the envy of the world, with 15 million new jobs, low unemployment, and declining inflation. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's plan for prescription drug costs? Answer: Biden wants to cap insulin costs at $35/month for all Americans and give Medicare power to negotiate prices for 500 drugs. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What did Biden propose regarding housing? Answer: Biden proposed a $400/month tax credit for two years to help with mortgage costs and plans to build 2 million affordable homes. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on education? Answer: Biden wants to provide access to preschool for 3-4 year olds, expand tutoring, and make college more affordable through increased Pell Grants. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What did Biden say about taxes? Answer: Biden proposed a 25% minimum tax on billionaires and raising the corporate minimum tax to 21% to make the wealthy pay their fair share. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's stance on Social Security? Answer: Biden vowed to protect Social Security and Medicare, opposing any cuts or raising of the retirement age. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What did Biden say about immigration? Answer: Biden called for passing a bipartisan border security bill that would hire more agents, judges, and provide new policies to resolve cases faster. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on gun control? Answer: Biden called for banning assault weapons and high-capacity magazines, as well as passing universal background checks. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What did Biden say about the Israel-Hamas conflict? Answer: Biden affirmed Israel's right to go after Hamas but said Israel has a responsibility to protect innocent civilians in Gaza. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What new action did Biden announce regarding Gaza? Answer: Biden directed the U.S. military to establish a temporary pier on Gaza's coast to increase humanitarian aid delivery. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's stance on China? Answer: Biden said he wants competition, not conflict with China, and has taken steps to counter China's economic practices and protect U.S. technology. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: How did Biden address concerns about his age? Answer: Biden said the issue isn't how old we are, but how old our ideas are, emphasizing his vision for the future over 'ancient ideas'."
"Question: What is Biden's policy on reproductive rights? Answer: Biden supports restoring Roe v. Wade and guaranteeing the right to IVF nationwide. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's plan for climate change? Answer: Biden aims to cut carbon emissions in half by 2030 and create clean energy jobs, including expanding the Climate Corps. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on workers' rights? Answer: Biden supports passing the PRO Act for workers' rights and raising the federal minimum wage. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's stance on LGBTQ+ rights? Answer: Biden called for passing the Equality Act and expressed support for transgender Americans. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's plan for healthcare? Answer: Biden wants to expand the Affordable Care Act and launch a White House Initiative on Women's Health Research. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on crime and policing? Answer: Biden supports investing in community policing, mental health workers, and community violence intervention. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's plan for veterans? Answer: Biden highlighted the PACT Act, which provides support for veterans exposed to toxins. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on Iran? Answer: Biden is focused on containing the threat posed by Iran and defending international shipping in the Red Sea. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's plan for AI regulation? Answer: Biden called for legislation to protect children online and regulate AI, including banning AI voice impersonations. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on fentanyl and drug trafficking? Answer: Biden wants to strengthen penalties on fentanyl trafficking. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's plan for infrastructure? Answer: Biden highlighted the bipartisan infrastructure law funding projects across the country. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on manufacturing? Answer: Biden supports 'Buy American' policies and bringing manufacturing jobs back to the US. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's plan for small businesses? Answer: Biden highlighted record small business growth and support for entrepreneurs. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's policy on the Middle East peace process? Answer: Biden supports a two-state solution for Israel and Palestine. Source:  2024 state of the union address March 8, 2024 https://www.congress.gov/118/meeting/house/116942/documents/HHRG-118-JU00-20240312-SD001.pdf",
"Question: What is Biden's plan for reducing the federal deficit? Answer: Biden aims to cut the deficit by $3 trillion through tax reforms on corporations and the wealthy."

]

# %% [markdown]
# Source:
# July 12, 2024
# Remarks by President Biden at a Campaign Event Renaissance High School
# Detroit, Michigan 7:24 P.M. EDT  https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/

# %%
corpus += [
"Question: What is Biden's policy on women's rights?, Answer: Biden pledges to stand up for women in America, protect contraception and IVF, and restore Roe v. Wade as the law of the land. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for healthcare?, Answer: Biden plans to keep lowering prescription drug costs, expand healthcare, and protect the Affordable Care Act. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on gun control?, Answer: Biden wants to get weapons of war off the streets and ban assault weapons. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: How does Biden compare his job creation record to Trump's?, Answer: Biden claims he created 275,000 auto jobs in America, while under Trump, 86,000 union jobs were lost. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's economic plan?, Answer: Biden's plan focuses on job creation, lowering inflation, and taking on corporate greed. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: How does Biden plan to address Social Security and Medicare?, Answer: Biden plans to expand and strengthen Social Security and Medicare, making the rich pay their fair share. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on unions?, Answer: Biden strongly supports unions, stating that unions built the middle class. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for housing?, Answer: Biden plans to build 2 million housing units and cap rent increases at 5% a year to make housing more affordable. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's tax policy?, Answer: Biden plans to end Trump's tax cuts for the wealthy and corporations, and make billionaires pay a minimum 25% tax rate. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for the southern border?, Answer: Biden plans to continue securing the southern border, fix legal immigration, and create pathways for citizenship for DREAMers. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: How does Biden characterize Trump's leadership?, Answer: Biden portrays Trump as a threat to the nation, calling him unhinged and accusing him of attempting to overturn the 2020 election. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on climate change?, Answer: Biden plans to continue leading the world on climate and clean energy initiatives. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for child poverty?, Answer: Biden wants to make the Child Care Tax Credit permanent to help reduce child poverty. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for prescription drug costs?, Answer: Biden plans to extend the $2,000 annual cap on prescription drug costs to all Americans, not just seniors."
"Question: Where did President Biden give this speech?, Answer: President Biden gave this speech at Renaissance High School in Detroit, Michigan. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on women's rights?, Answer: Biden pledges to stand up for women in America, protect contraception and IVF, and restore Roe v. Wade as the law of the land. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for healthcare?, Answer: Biden plans to keep lowering prescription drug costs, expand healthcare, and protect the Affordable Care Act. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on gun control?, Answer: Biden wants to get weapons of war off the streets and ban assault weapons. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: How does Biden compare his job creation record to Trump's?, Answer: Biden claims he created 275,000 auto jobs in America, while under Trump, 86,000 union jobs were lost. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's economic plan?, Answer: Biden's plan focuses on job creation, lowering inflation, and taking on corporate greed. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: How does Biden plan to address Social Security and Medicare?, Answer: Biden plans to expand and strengthen Social Security and Medicare, making the rich pay their fair share. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on unions?, Answer: Biden strongly supports unions, stating that unions built the middle class. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for housing?, Answer: Biden plans to build 2 million housing units and cap rent increases at 5% a year to make housing more affordable. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's tax policy?, Answer: Biden plans to end Trump's tax cuts for the wealthy and corporations, and make billionaires pay a minimum 25% tax rate. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for the southern border?, Answer: Biden plans to continue securing the southern border, fix legal immigration, and create pathways for citizenship for DREAMers. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: How does Biden characterize Trump's leadership?, Answer: Biden portrays Trump as a threat to the nation, calling him unhinged and accusing him of attempting to overturn the 2020 election. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on climate change?, Answer: Biden plans to continue leading the world on climate and clean energy initiatives. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for child poverty?, Answer: Biden wants to make the Child Care Tax Credit permanent to help reduce child poverty. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for prescription drug costs?, Answer: Biden plans to extend the $2,000 annual cap on prescription drug costs to all Americans, not just seniors. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on voting rights?, Answer: Biden plans to sign the John Lewis Voting Rights Act and the Freedom to Vote Act. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for the minimum wage?, Answer: Biden plans to raise the federal minimum wage. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on labor laws?, Answer: Biden plans to pass the PRO Act to end union busting. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for medical debt?, Answer: Biden plans to end medical debt by ensuring it can't be put on credit reports and wiping it out for pennies on the dollar. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on education?, Answer: Biden opposes Trump's plan to eliminate the Department of Education and cut school lunch programs. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on immigration?, Answer: Biden opposes Trump's plan to round up over 10 million people and put them in detention camps. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for the first 100 days of his second term?, Answer: Biden plans to introduce bills to restore Roe v. Wade, sign voting rights acts, expand Social Security and Medicare, and implement other key policies. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on overtime pay?, Answer: Biden opposes Trump's plan to allow employers to stop paying overtime for hourly workers. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on NATO?, Answer: Biden takes credit for strengthening and expanding NATO. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on Ukraine?, Answer: Biden supports Ukraine against Russian invasion, criticizing Trump for calling Putin a 'genius'. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for the auto industry?, Answer: Biden supports the auto industry and union auto workers, having walked a picket line with UAW workers.",
"Question: What is Biden's stance on corporate accountability?, Answer: Biden is against corporate greed and supports making corporations pay their fair share of taxes. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on inflation?, Answer: Biden claims his economic plan has lowered inflation and will continue to work on reducing it further. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for manufacturing jobs?, Answer: Biden boasts creating 800,000 manufacturing jobs nationwide, including 24,000 in Michigan. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on classified information handling?, Answer: Biden criticizes Trump for mishandling classified information, which he considers a criminal offense. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on pardons for January 6th insurrectionists?, Answer: Biden strongly opposes Trump's plan to pardon January 6th insurrectionists. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on the 'Project 2025'?, Answer: Biden opposes Trump's 'Project 2025', calling it the biggest attack on the U.S. system of government and personal freedom ever proposed. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for the Department of Justice?, Answer: Biden opposes using the Department of Justice to prosecute political enemies, contrasting with Trump's alleged plans. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on civil service?, Answer: Biden opposes Trump's plan to eliminate the civil service system and replace it with political appointees. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on Head Start programs?, Answer: Biden opposes Trump's alleged plan to eliminate Head Start for low-income children. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on insulin costs?, Answer: Biden supports maintaining the $35 monthly cap on insulin costs for seniors and wants to extend this benefit to all Americans. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's plan for cancer drug costs?, Answer: Biden supports capping the annual cost of all prescription drugs, including cancer drugs, at $2,000 for seniors and wants to extend this to all Americans. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on green cards?, Answer: Biden plans to provide green cards to spouses of Americans who have been in the country for over 10 years without one. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on trickle-down economics?, Answer: Biden declares that the days of failed trickle-down economics are over, focusing instead on policies for working people. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's policy on the Palestine-Israel conflict?, Answer: Biden mentions having a detailed plan accepted by the UN, Israelis, and Palestinians to end the war, emphasizing that the war must end. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
"Question: What is Biden's stance on democracy protection?, Answer: Biden emphasizes protecting democracy and the Constitution, opposing what he sees as Trump's authoritarian tendencies. Source: July 12, 2024 Remarks by President Biden at a Campaign Event Renaissance High School Detroit, Michigan 7:24 P.M. EDT https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/12/remarks-by-president-biden-at-a-campaign-event-detroit-mi-3/",
]

# %% [markdown]
# Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/

# %%
corpus += [
"Question: Where did Vice President Harris speak in Wisconsin?, Answer: Vice President Harris gave this speech at West Allis Central High School in West Allis, Wisconsin. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What was the main purpose of Harris's visit to Wisconsin?, Answer: Harris was in Wisconsin for a political event to campaign for the 2024 presidential election. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What milestone did Harris announce regarding the Democratic nomination?, Answer: Harris announced that she had earned enough delegates to secure the Democratic nomination for president. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How did Harris describe President Biden's accomplishments?, Answer: Harris said Biden's legacy of accomplishment in one term has surpassed most two-term presidents and is 'unmatched in modern history'. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How did Harris contrast her background with Donald Trump's?, Answer: Harris highlighted her experience as a prosecutor and Attorney General taking on predators and fraudsters, contrasting it with Trump's fraud convictions and sexual abuse liability. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What did Harris say about the campaign's fundraising?, Answer: Harris announced they just had the best 24 hours of grassroots fundraising in presidential campaign history. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What did Harris say would be a defining goal of her presidency?, Answer: Harris said building up the middle class would be a defining goal of her presidency. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How did Harris characterize Trump's economic policies?, Answer: Harris said Trump wants to take the country backward with policies that would weaken the middle class, including cutting Social Security and Medicare. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What did Harris say about reproductive rights?, Answer: Harris pledged to stop Trump's 'extreme abortion bans' and sign a law restoring reproductive freedoms if passed by Congress. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What key themes did Harris emphasize for the campaign?, Answer: Harris emphasized themes of fighting for the future, freedom, and opportunity for all Americans. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How many days did Harris say were left until Election Day?, Answer: Harris said there were 105 days left until Election Day. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What did Harris ask supporters to do in the coming months?, Answer: Harris asked supporters to knock on doors, make phone calls, register voters, and work to win the election. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's stance on healthcare?, Answer: Harris supports affordable healthcare for all and opposes ending the Affordable Care Act. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's position on labor unions?, Answer: Harris supports workers having the freedom to join unions. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's policy on childcare?, Answer: Harris supports making childcare more affordable for families. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's stance on paid family leave?, Answer: Harris supports providing paid family leave. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's position on retirement security?, Answer: Harris believes every senior should be able to retire with dignity. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's stance on gun control?, Answer: Harris supports passing red flag laws, universal background checks, and an assault weapons ban. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's position on voting rights?, Answer: Harris supports ensuring every American has the ability to cast their ballot and have it counted. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How does Harris plan to address child poverty?, Answer: Harris believes in creating a future where no child has to grow up in poverty. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's stance on corporate influence in politics?, Answer: Harris criticized Trump for relying on billionaires and big corporations, contrasting it with her 'people-powered' campaign. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How does Harris plan to approach economic policy?, Answer: Harris emphasized strengthening the middle class as key to making America strong. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's position on tax policy?, Answer: Harris opposes tax breaks for billionaires and big corporations at the expense of working families. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
]

# %% [markdown]
# https://democrats.org/where-we-stand/party-platform/
#
# https://democrats.org/wp-content/uploads/2020/08/2020-Democratic-Party-Platform.pdf

# %% [markdown]
# # Vanilla TF-IDF Code

# %%
# -*- coding: utf-8 -*-



"""
vanilla_TF-IDF_v5.ipynb

This notebook is based on:
- https://medium.com/@coldstart_coder/understanding-and-implementing-tf-idf-in-python-a325d1301484
- https://www.kaggle.com/code/tylerpoff/understanding-and-implementing-tf-idf-in-python/notebook
"""

import math
import time



"""# query"""
query = query

corpus_unsplit = corpus



def term_frequency(word, document):
    return document.count(word) / len(document)
tf = term_frequency

# # non-plus-1 variant ("unsafe" variant)
# def inverse_document_frequency_unsafe(word, corpus):
#     count_of_documents = len(corpus)
#     count_of_documents_with_word = sum([1 for doc in corpus if word in doc])
#     idf = math.log10(count_of_documents/count_of_documents_with_word)
#     return idf

# sklearn variant
def inverse_document_frequency(word, corpus):
    count_of_documents = len(corpus) + 1
    count_of_documents_with_word = sum([1 for doc in corpus if word in doc]) + 1
    idf = math.log10(count_of_documents/count_of_documents_with_word) + 1
    return idf

idf = inverse_document_frequency

def TF_IDF(word, document, corpus):
    return tf(word, document) * idf(word, corpus)


"""# corpus of documents"""
split_corpus = [c.split() for c in corpus_unsplit]
num_documents = len(split_corpus)


"""### Optional Sample Target Word Analysis"""

"""
optional
"""
# target_word = "Expert"

# print("searching for the word '%s'"%target_word)
# for i, document in enumerate(split_corpus):
#     tf_score = tf(target_word, document)
#     idf_score = idf(target_word, split_corpus)
#     tf_idf_score = TF_IDF(target_word, document, split_corpus)

#     print("document %s: '%s'\n    tf score: %s\n    idf score: %s\n    tf_idf score:%s"%(i, document, tf_score, idf_score, tf_idf_score))
#     print("-"*30)

"""## word to vector mappings"""

"""
 create the word to vector mappings,
 we want each word to map to a unique point in our word vectors.
combine the complete corpus into a single list of words; remove duplicates.
use position in this list as the index for a word vector
"""
word_set = list(set(sum(split_corpus, [])))
# create a lookup for each word to it's index,
word_to_index = {word:i for i, word in enumerate(word_set)}

num_words = len(word_set)


"""## create the word vectors"""
# create an empty list to store our word vectors
word_vectors = []
for document in split_corpus:
    # for our new document create a new word vector
    new_word_vector = [0 for i in range(num_words)]

    # now we loop through each word in our document and compute the tf-idf score and populate our vector with it,
    # we only care about words in this document because words outside of it will remain zero
    for word in document:
        # get the score
        tf_idf_score = TF_IDF(word, document, split_corpus)
        # next get the index for this word in our word vector
        word_index = word_to_index[word]
        # populate the vector
        new_word_vector[word_index] = tf_idf_score

    # don't forget to add this new word vector to our list of existing word_vectors
    word_vectors.append(new_word_vector)


"""## one word vector in comparision to document"""
# # inspection
# print(corpus_unsplit[0])
# print(word_vectors[0])


"""## <b>Searching with TF-IDF Sparse Vectors</b>"""
query_keywords = query.split()

# now we loop through each documents word vector, get the tf-idf score for each keyword, sum them up and that is our tf-idf for that document,
# we keep track of the best document and return that as our result,
tf_idf_scores = []
best_document_index = 0
best_tf_idf = 0

for i, word_vector in enumerate(word_vectors):
    document_tf_idf_score_for_query = 0
    for word in query_keywords:
        # first do a check, does this word appear in our split_corpus of documents?
        # if not skip this keyword
        if word not in word_set:
            continue

        # get the index for this keyword and directly pull it from the word vector
        word_index = word_to_index[word]
        document_tf_idf_score_for_query += word_vector[word_index]
    tf_idf_scores.append(document_tf_idf_score_for_query) # keep track of all tf_idf scores, just in case we want to review them,

    """
    optional:
    top N list...TODO
    """
    # does this tf_idf score for this document beat our previous best?
    if document_tf_idf_score_for_query > best_tf_idf:
        best_tf_idf = document_tf_idf_score_for_query
        best_document_index = i

# from pprint import pprint
# # then print out our results
# # print("results of query: ", query)
# print("best tf_idf score sum for query: ", best_tf_idf)
# print("best document: ", corpus_unsplit[best_document_index])
# print("complete list of tf_idf scores: ", tf_idf_scores)

# pprint(tf_idf_scores)
# pprint(corpus_unsplit)



def search_top_n(query, corpus, n):
    query_keywords = query.split()

    tf_idf_scores = []
    for i, word_vector in enumerate(word_vectors):
        document_tf_idf_score_for_query = 0
        for word in query_keywords:
            if word not in word_set:
                continue

            word_index = word_to_index[word]
            document_tf_idf_score_for_query += word_vector[word_index]
        tf_idf_scores.append((document_tf_idf_score_for_query, i))

    # Sort the TF-IDF scores in descending order
    tf_idf_scores.sort(reverse=True)

    # Extract the document indices from the top-N results
    top_n_document_indices = [index for _, index in tf_idf_scores[:n]]

    # Return the top-N documents and their TF-IDF scores
    top_n_documents = [corpus[index] for index in top_n_document_indices]
    top_n_tf_idf_scores = [score for score, _ in tf_idf_scores[:n]]

    return top_n_documents, top_n_tf_idf_scores

# %% [markdown]
# # Use TF-IDF

# %%
# Set This
how_many_results = 5

# Search
top_n = how_many_results
start_time = time.monotonic()  # timer
top_n_documents, top_n_tf_idf_scores = search_top_n(query, corpus_unsplit, top_n)
end_time = time.monotonic()  # timer
elapsed_time = end_time - start_time  # timer

print(f"Top-{top_n} results for query: {query}")
for i, (document, score) in enumerate(zip(top_n_documents, top_n_tf_idf_scores)):
    print(f"Result {i+1}:")
    print(f"TF-IDF score: {score}")
    print(f"Document: {document}\n")
# timer
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Top-5 results for query: reproductive rights
# Result 1:
# TF-IDF score: 0.15656329866236152
# Document: Question: What is Biden's position on reproductive freedom?, Answer: Biden believes reproductive health care decisions should be made by women with their doctors, not politicians, and opposes a national abortion ban. Source: https://joebiden.com/issues/ (2024.07.13)
#
# Result 2:
# TF-IDF score: 0.13481151554088333
# Document: Question: How has Biden responded to the overturning of Roe v. Wade?, Answer: Biden has taken action to protect and strengthen reproductive health care access, including signing executive orders and fighting for women's rights to emergency medical care. Source: https://joebiden.com/issues/ (2024.07.13)
#
# Result 3:
# TF-IDF score: 0.12282826971502706
# ...

# %% [markdown]
# # BM-25 Code

# %%
#!/usr/bin/env python
"""
https://www.cs.otago.ac.nz/homepages/andrew/papers/2014-2.pdf
    BM25: https://www.cs.otago.ac.nz/homepages/andrew/papers/2014-2.pdf
    https://github.com/dorianbrown/rank_bm25
    https://github.com/dorianbrown/rank_bm25/blob/master/rank_bm25.py
"""

import math
import numpy as np
from multiprocessing import Pool, cpu_count

"""
All of these algorithms have been taken from the paper:
Trotmam et al, Improvements to BM25 and Language Models Examined

Here we implement all the BM25 variations mentioned.
"""


class BM25:
    def __init__(self, corpus, tokenizer=None):
        self.corpus_size = 0
        self.avgdl = 0
        self.doc_freqs = []
        self.idf = {}
        self.doc_len = []
        self.tokenizer = tokenizer

        if tokenizer:
            corpus = self._tokenize_corpus(corpus)

        nd = self._initialize(corpus)
        self._calc_idf(nd)

    def _initialize(self, corpus):
        nd = {}  # word -> number of documents with word
        num_doc = 0
        for document in corpus:
            self.doc_len.append(len(document))
            num_doc += len(document)

            frequencies = {}
            for word in document:
                if word not in frequencies:
                    frequencies[word] = 0
                frequencies[word] += 1
            self.doc_freqs.append(frequencies)

            for word, freq in frequencies.items():
                try:
                    nd[word]+=1
                except KeyError:
                    nd[word] = 1

            self.corpus_size += 1

        self.avgdl = num_doc / self.corpus_size
        return nd

    def _tokenize_corpus(self, corpus):
        pool = Pool(cpu_count())
        tokenized_corpus = pool.map(self.tokenizer, corpus)
        return tokenized_corpus

    def _calc_idf(self, nd):
        raise NotImplementedError()

    def get_scores(self, query):
        raise NotImplementedError()

    def get_batch_scores(self, query, doc_ids):
        raise NotImplementedError()

    def get_top_n(self, query, documents, n=5):

        assert self.corpus_size == len(documents), "The documents given don't match the index corpus!"

        scores = self.get_scores(query)
        top_n = np.argsort(scores)[::-1][:n]
        return [documents[i] for i in top_n]


class BM25Okapi(BM25):
    def __init__(self, corpus, tokenizer=None, k1=1.5, b=0.75, epsilon=0.25):
        self.k1 = k1
        self.b = b
        self.epsilon = epsilon
        super().__init__(corpus, tokenizer)

    def _calc_idf(self, nd):
        """
        Calculates frequencies of terms in documents and in corpus.
        This algorithm sets a floor on the idf values to eps * average_idf
        """
        # collect idf sum to calculate an average idf for epsilon value
        idf_sum = 0
        # collect words with negative idf to set them a special epsilon value.
        # idf can be negative if word is contained in more than half of documents
        negative_idfs = []
        for word, freq in nd.items():
            idf = math.log(self.corpus_size - freq + 0.5) - math.log(freq + 0.5)
            self.idf[word] = idf
            idf_sum += idf
            if idf < 0:
                negative_idfs.append(word)
        self.average_idf = idf_sum / len(self.idf)

        eps = self.epsilon * self.average_idf
        for word in negative_idfs:
            self.idf[word] = eps

    def get_scores(self, query):
        """
        The ATIRE BM25 variant uses an idf function which uses a log(idf) score. To prevent negative idf scores,
        this algorithm also adds a floor to the idf value of epsilon.
        See [Trotman, A., X. Jia, M. Crane, Towards an Efficient and Effective Search Engine] for more info
        :param query:
        :return:
        """
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            score += (self.idf.get(q) or 0) * (q_freq * (self.k1 + 1) /
                                               (q_freq + self.k1 * (1 - self.b + self.b * doc_len / self.avgdl)))
        return score

    def get_batch_scores(self, query, doc_ids):
        """
        Calculate bm25 scores between query and subset of all docs
        """
        assert all(di < len(self.doc_freqs) for di in doc_ids)
        score = np.zeros(len(doc_ids))
        doc_len = np.array(self.doc_len)[doc_ids]
        for q in query:
            q_freq = np.array([(self.doc_freqs[di].get(q) or 0) for di in doc_ids])
            score += (self.idf.get(q) or 0) * (q_freq * (self.k1 + 1) /
                                               (q_freq + self.k1 * (1 - self.b + self.b * doc_len / self.avgdl)))
        return score.tolist()


class BM25L(BM25):
    def __init__(self, corpus, tokenizer=None, k1=1.5, b=0.75, delta=0.5):
        # Algorithm specific parameters
        self.k1 = k1
        self.b = b
        self.delta = delta
        super().__init__(corpus, tokenizer)

    def _calc_idf(self, nd):
        for word, freq in nd.items():
            idf = math.log(self.corpus_size + 1) - math.log(freq + 0.5)
            self.idf[word] = idf

    def get_scores(self, query):
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            ctd = q_freq / (1 - self.b + self.b * doc_len / self.avgdl)
            score += (self.idf.get(q) or 0) * (self.k1 + 1) * (ctd + self.delta) / \
                     (self.k1 + ctd + self.delta)
        return score

    def get_batch_scores(self, query, doc_ids):
        """
        Calculate bm25 scores between query and subset of all docs
        """
        assert all(di < len(self.doc_freqs) for di in doc_ids)
        score = np.zeros(len(doc_ids))
        doc_len = np.array(self.doc_len)[doc_ids]
        for q in query:
            q_freq = np.array([(self.doc_freqs[di].get(q) or 0) for di in doc_ids])
            ctd = q_freq / (1 - self.b + self.b * doc_len / self.avgdl)
            score += (self.idf.get(q) or 0) * (self.k1 + 1) * (ctd + self.delta) / \
                     (self.k1 + ctd + self.delta)
        return score.tolist()


class BM25Plus(BM25):
    def __init__(self, corpus, tokenizer=None, k1=1.5, b=0.75, delta=1):
        # Algorithm specific parameters
        self.k1 = k1
        self.b = b
        self.delta = delta
        super().__init__(corpus, tokenizer)

    def _calc_idf(self, nd):
        for word, freq in nd.items():
            idf = math.log(self.corpus_size + 1) - math.log(freq)
            self.idf[word] = idf

    def get_scores(self, query):
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            score += (self.idf.get(q) or 0) * (self.delta + (q_freq * (self.k1 + 1)) /
                                               (self.k1 * (1 - self.b + self.b * doc_len / self.avgdl) + q_freq))
        return score

    def get_batch_scores(self, query, doc_ids):
        """
        Calculate bm25 scores between query and subset of all docs
        """
        assert all(di < len(self.doc_freqs) for di in doc_ids)
        score = np.zeros(len(doc_ids))
        doc_len = np.array(self.doc_len)[doc_ids]
        for q in query:
            q_freq = np.array([(self.doc_freqs[di].get(q) or 0) for di in doc_ids])
            score += (self.idf.get(q) or 0) * (self.delta + (q_freq * (self.k1 + 1)) /
                                               (self.k1 * (1 - self.b + self.b * doc_len / self.avgdl) + q_freq))
        return score.tolist()


"""
BM25Adpt and BM25T are a bit more complicated than the previous algorithms here. Here a term-specific k1
parameter is calculated before scoring is done
"""

class BM25Adpt(BM25):
    def __init__(self, corpus, k1=1.5, b=0.75, delta=1):
        # Algorithm specific parameters
        self.k1 = k1
        self.b = b
        self.delta = delta
        super().__init__(corpus)

    def _calc_idf(self, nd):
        for word, freq in nd.items():
            idf = math.log((self.corpus_size + 1) / freq)
            self.idf[word] = idf

    def get_scores(self, query):
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            score += (self.idf.get(q) or 0) * (self.delta + (q_freq * (self.k1 + 1)) /
                                               (self.k1 * (1 - self.b + self.b * doc_len / self.avgdl) + q_freq))
        return score

    def get_top_n(self, query, documents, n=5):

        assert self.corpus_size == len(documents), "The documents given don't match the index corpus!"

        scores = self.get_scores(query)
        top_n = np.argsort(scores)[::-1][:n]
        return [documents[i] for i in top_n]

class BM25T(BM25):
    def __init__(self, corpus, k1=1.5, b=0.75, delta=1):
        # Algorithm specific parameters
        self.k1 = k1
        self.b = b
        self.delta = delta
        super().__init__(corpus)

    def _calc_idf(self, nd):
        for word, freq in nd.items():
            idf = math.log((self.corpus_size + 1) / freq)
            self.idf[word] = idf

    def get_scores(self, query):
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            score += (self.idf.get(q) or 0) * (self.delta + (q_freq * (self.k1 + 1)) /
                                               (self.k1 * (1 - self.b + self.b * doc_len / self.avgdl) + q_freq))
        return score


    def get_top_n(self, query, documents, n=5):

        assert self.corpus_size == len(documents), "The documents given don't match the index corpus!"

        scores = self.get_scores(query)
        top_n = np.argsort(scores)[::-1][:n]
        return [documents[i] for i in top_n]

# %%
"""
https://github.com/dorianbrown/rank_bm25
https://pypi.org/project/rank-bm25/
https://www.cs.otago.ac.nz/homepages/andrew/papers/2014-2.pdf

"""
# !pip install -q git+https://git@github.com/dorianbrown/rank_bm25.git
# from rank_bm25 import BM25Okapi

import time


# # Tokenize the documents

# tokenized_corpus = [doc.split(" ") for doc in corpus]

# # Create a BM25 object
# bm25 = BM25Okapi(tokenized_corpus)

# # Tokenize the query
# tokenized_query = query.split(" ")

# # Calculate BM25 scores for the query
# scores = bm25.get_scores(tokenized_query)

# # Print the scores
# for i, score in enumerate(scores):
#     print(f"Document {i}: {score}")

# %% [markdown]
#  # Use BM-25

# %%
# Set This
how_many_results = 5

# Preprocessing Text
start_time = time.monotonic()  # timer
tokenized_corpus = [doc.split(" ") for doc in corpus]
bm25 = BM25Okapi(tokenized_corpus)  # Create a BM25 object
tokenized_query = query.split(" ")  # Tokenize the query

# Search
top_n = bm25.get_top_n(tokenized_query, corpus, n=how_many_results)
end_time = time.monotonic()  # timer
elapsed_time = end_time - start_time   # timer

# Print
for i in top_n:
    print(i)
# timer
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Question: How has Biden responded to the overturning of Roe v. Wade?, Answer: Biden has taken action to protect and strengthen reproductive health care access, including signing executive orders and fighting for women's rights to emergency medical care. Source: https://joebiden.com/issues/ (2024.07.13)
# Joe Biden supports women's rights and is fighting to restore the protections of Roe vs. Wade. He opposes a federal abortion ban. He believes reproductive health care decisions should be made by people and their doctors, not by politicians. Source: PA-DEMS On Board FAQ: https://drive.google.com/file/d/15xjEXajjvEmO5n9OJf3LV15G9PPjQABh/view
# Question: What is Biden's position on reproductive freedom?, Answer: Biden believes reproductive health care decisions should be made by women with their doctors, not politicians, and opposes a national abortion ban. Source: https://joebiden.com/issues/ (2024.07.13)
# ...
